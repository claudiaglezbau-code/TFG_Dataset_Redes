# %%
"""
MODELO DE HESTON — TFG — V1
Fórmula Cerrada + Carr-Madan FFT + Red Neuronal Surrogate (4 x 256)
"""

import numpy as np
from scipy import fftpack, integrate
from math import pi
import csv, time
import pandas as pd
import matplotlib.pyplot as plt
import joblib

import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Constantes

S0  = 100.0
r   = 0.0
EPS = 1e-12

STRIKES_PCT = np.array([0.80, 0.85, 0.90, 0.95, 0.97, 0.99,
                         1.00, 1.01, 1.02, 1.05, 1.10, 1.15, 1.20])
MATURITIES  = np.array([0.1, 0.25, 0.5, 1.0])

TARGET_FILAS          = 100_000
PUNTOS_POR_SUPERFICIE = len(STRIKES_PCT) * len(MATURITIES)        # 52
N_SUPERFICIES         = int(np.ceil(TARGET_FILAS / PUNTOS_POR_SUPERFICIE))  # 1924
OUTFILE               = "dataset_heston_100k.csv"

SEED      = 42
TEST_SIZE = 0.15
VAL_SIZE  = 0.15
PARAMS_COLS = ['kappa', 'theta', 'sigma', 'rho', 'v0']


# BLOQUE 1 — Función característica de Heston


def caracteristica_heston(phi, params, S0_local, r_local, T, Pnum=2, unwrap_log=False):
    kappa, theta, sigma, rho, v0 = params
    phi    = np.array(phi, dtype=complex)
    i      = 1j
    u      = 0.5 if Pnum == 1 else -0.5
    b      = (kappa - rho * sigma) if Pnum == 1 else kappa
    a      = kappa * theta
    sigma2 = max(sigma**2, EPS)

    alpha = -0.5 * (phi**2) + i * u * phi
    beta  = b - rho * sigma * i * phi
    d     = np.sqrt(beta**2 - 2.0 * sigma2 * alpha)
    g     = (beta - d) / (beta + d)

    exp_dt         = np.exp(-d * T)
    one_minus_gexp = 1.0 - g * exp_dt
    one_minus_g    = 1.0 - g

    one_minus_gexp = np.where(np.abs(one_minus_gexp) < EPS, EPS, one_minus_gexp)
    one_minus_g    = np.where(np.abs(one_minus_g)    < EPS, EPS, one_minus_g)

    log_term = np.log(one_minus_gexp / one_minus_g)

    # Lord-Kahl (2010): el logaritmo complejo puede saltar de rama (±2πi)
    # conforme phi recorre la rejilla FFT. np.unwrap corrige esos saltos
    # forzando continuidad en la parte imaginaria.
    if unwrap_log and phi.ndim > 0 and len(phi) > 1:
        log_term = log_term.real + 1j * np.unwrap(log_term.imag)

    C = (1j * phi * r_local * T) + (a / sigma2) * ((beta - d) * T - 2.0 * log_term)
    D = ((beta - d) / sigma2) * (1.0 - exp_dt) / one_minus_gexp

    return np.exp(C + D * v0 + 1j * phi * np.log(S0_local))


# BLOQUE 2 — Fórmula cerrada Heston (1993)


def _integrando(phi, params, S0_local, r_local, T, K, Pnum):
    cf  = caracteristica_heston(phi, params, S0_local, r_local, T, Pnum)
    val = np.exp(-1j * phi * np.log(K)) * cf / (1j * phi)
    return np.real(val)


def heston_precio_cerrado(params, S0_local, r_local, T, K, tol=1e-6, limit=200):
    I2, _ = integrate.quad(_integrando, 0, np.inf,
                            args=(params, S0_local, r_local, T, K, 2),
                            limit=limit, epsabs=tol, epsrel=tol)
    P2 = 0.5 + I2 / pi

    I1, _ = integrate.quad(_integrando, 0, np.inf,
                            args=(params, S0_local, r_local, T, K, 1),
                            limit=limit, epsabs=tol, epsrel=tol)
    P1 = 0.5 + I1 / pi

    return max(0.0, S0_local * P1 - K * np.exp(-r_local * T) * P2)


def verificar_formula_cerrada(params, T=0.5, K=100.0):
    precio_cerrado = heston_precio_cerrado(params, S0, r, T, K)
    K_fft, P_fft   = carr_madan_fft(params, S0, r, T)
    precio_cm      = float(np.interp(K, K_fft, P_fft))

    print(f"\n  Heston 1993 (integración directa) : {precio_cerrado:.6f} €")
    print(f"  Carr-Madan FFT                    : {precio_cm:.6f} €")
    print(f"  Diferencia                        : {abs(precio_cerrado - precio_cm):.2e} €")
    return precio_cerrado, precio_cm



# BLOQUE 3 — Carda-madan FFT


def carr_madan_fft(params, S0_local, r_local, T, alpha=1.5, N=4096, eta=0.2):
    i      = 1j
    lambd  = 2 * pi / (N * eta)
    b      = N * lambd / 2

    v      = np.arange(N) * eta
    phi    = v - (alpha + 1) * i

    char_vals  = caracteristica_heston(phi, params, S0_local, r_local, T, Pnum=2, unwrap_log=True)
    numerator  = np.exp(-r_local * T) * char_vals * np.exp(i * b * v)
    denom      = (alpha + i * v) * (alpha + i * v + 1)

    # ── Pesos de Simpson (Carr-Madan 1999) ──────────────────
    j = np.arange(N)
    w = 3 + (-1)**(j + 1)
    w[0] = 1

    fft_vals   = fftpack.fft((numerator / denom) * (eta / 3) * w).real

    k       = -b + j * lambd
    K_grid  = np.exp(k)
    precios = np.exp(-alpha * k) / pi * fft_vals

    return K_grid, precios



# BLOQUE 4 — Generación deel dataset (100.000 filas)


def generar_paramsets_validos(n_needed, seed=SEED):
    rng        = np.random.default_rng(seed)
    valid_sets = []
    intentos   = 0
    while len(valid_sets) < n_needed:
        intentos += 1
        k   = rng.uniform(0.5, 5.0)
        t   = rng.uniform(0.01, 0.15)
        s   = rng.uniform(0.01, 0.6)
        rho = rng.uniform(-0.9, -0.1)
        v0  = rng.uniform(0.01, 0.2)
        if 2 * k * t > s**2:
            valid_sets.append([k, t, s, rho, v0])

    tasa = len(valid_sets) / intentos * 100
    print(f"  Parámetros válidos: {n_needed} de {intentos} intentos ({tasa:.1f}% aceptación)")
    return np.array(valid_sets)


def crear_dataset(n_superficies, outfile=OUTFILE):
    print(f"\n  Superficies : {n_superficies:,}  |  Puntos/sup: {PUNTOS_POR_SUPERFICIE}  |  Objetivo: {n_superficies * PUNTOS_POR_SUPERFICIE:,} filas")

    paramsets   = generar_paramsets_validos(n_superficies)
    strike_grid = S0 * STRIKES_PCT
    header      = ["kappa", "theta", "sigma", "rho", "v0", "T", "K", "price", "price_noisy"]
    rng         = np.random.default_rng(SEED)
    written     = 0
    errores     = 0
    t_start     = time.time()

    with open(outfile, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(header)

        for idx, params in enumerate(paramsets):
            if (idx + 1) % 500 == 0:
                elapsed = time.time() - t_start
                rate    = written / elapsed if elapsed > 0 else 1
                eta_s   = (TARGET_FILAS - written) / rate
                print(f"  [{idx+1:>5}/{n_superficies}]  {written:>8,} filas  "
                      f"({rate:.0f} filas/s)  ETA: {eta_s:.0f}s")

            for T in MATURITIES:
                try:
                    K_fft, P_fft   = carr_madan_fft(params, S0, r, T)
                    precios_interp = np.interp(strike_grid, K_fft, P_fft)
                    for j, K_val in enumerate(strike_grid):
                        base  = max(0.0, float(precios_interp[j]))
                        noisy = max(0.0, base * (1.0 + rng.normal(0.0, 0.01)))
                        writer.writerow([*params, float(T), float(K_val), base, noisy])
                        written += 1
                except Exception:
                    errores += 1
                    continue

    print(f"\n  Archivo   : {outfile}")
    print(f"  Filas     : {written:,}")
    print(f"  Errores   : {errores}")
    print(f"  Tiempo    : {(time.time()-t_start):.1f} s")
    return pd.read_csv(outfile)


# BLOQUE 5 — Validación del dataset


def validar_dataset(df):
    feller      = (2 * df['kappa'] * df['theta'] > df['sigma']**2).all()
    intrinseco  = (S0 - df['K']).clip(lower=0)
    violaciones = (df['price'] < intrinseco - 1e-5).sum()
    precios_neg = (df['price'] < 0).sum()

    print(f"\n  Filas totales    : {len(df):,}")
    print(f"  Paramsets únicos : {df[PARAMS_COLS].drop_duplicates().shape[0]:,}")
    print(f"  Feller cumplido  : {feller}  {'✓' if feller else '✗ REVISAR'}")
    print(f"  Precios negativos: {precios_neg}  {'✓' if precios_neg == 0 else '✗ REVISAR'}")
    print(f"  Violac. arbitraje: {violaciones}  {'✓' if violaciones == 0 else '✗ REVISAR'}")

    p0  = df.iloc[0][PARAMS_COLS].values
    sub = df[(df['kappa'] == p0[0]) & (df['theta'] == p0[1])]

    fig = plt.figure(figsize=(10, 6))
    ax  = fig.add_subplot(111, projection='3d')
    ax.plot_trisurf(sub['K'], sub['T'], sub['price'], cmap='viridis', alpha=0.85)
    ax.set_title(f"Superficie de Precios Heston (muestra)\n"
                 f"κ={p0[0]:.2f}, θ={p0[1]:.4f}, σ={p0[2]:.2f}, ρ={p0[3]:.2f}, v₀={p0[4]:.4f}")
    ax.set_xlabel("Strike K (€)")
    ax.set_ylabel("Vencimiento T (años)")
    ax.set_zlabel("Precio call (€)")
    plt.tight_layout()
    plt.savefig("superficie_heston.png", dpi=130)
    plt.show()


# BLOQUE 6 — Preparación dee datos


def preparar_datos(df):
    X = pd.DataFrame()
    X['log_moneyness'] = np.log(df['K'] / S0)
    X['sqrt_T']        = np.sqrt(df['T'].clip(lower=1e-12))
    X['kappa']         = df['kappa']
    X['log_theta']     = np.log(df['theta'].clip(lower=1e-8))
    X['sigma']         = df['sigma']
    X['rho']           = df['rho']
    X['log_v0']        = np.log(df['v0'].clip(lower=1e-8))

    y = (df['price'] / S0).values

    paramsets = df[PARAMS_COLS].drop_duplicates().reset_index(drop=True)
    rng       = np.random.default_rng(SEED)
    perm      = rng.permutation(len(paramsets))
    n_test    = int(len(paramsets) * TEST_SIZE)
    n_val     = int(len(paramsets) * VAL_SIZE)

    ps_test  = paramsets.iloc[perm[:n_test]]
    ps_val   = paramsets.iloc[perm[n_test:n_test + n_val]]
    ps_train = paramsets.iloc[perm[n_test + n_val:]]

    def mascara(ps):
        m = df[PARAMS_COLS].merge(ps, on=PARAMS_COLS, how='left', indicator=True)
        return (m['_merge'] == 'both').values

    m_train = mascara(ps_train)
    m_val   = mascara(ps_val)
    m_test  = mascara(ps_test)

    X_vals = X.values
    X_train_raw, y_train = X_vals[m_train], y[m_train]
    X_val_raw,   y_val   = X_vals[m_val],   y[m_val]
    X_test_raw,  y_test  = X_vals[m_test],  y[m_test]

    scaler  = StandardScaler()
    X_train = scaler.fit_transform(X_train_raw)
    X_val   = scaler.transform(X_val_raw)
    X_test  = scaler.transform(X_test_raw)

    joblib.dump(scaler, 'escalador_heston_nn.pkl')

    print(f"\n  Train : {X_train.shape[0]:>8,} filas  ({len(ps_train)} superficies)")
    print(f"  Val   : {X_val.shape[0]:>8,} filas  ({len(ps_val)} superficies)")
    print(f"  Test  : {X_test.shape[0]:>8,} filas  ({len(ps_test)} superficies)")

    return X_train, X_val, X_test, y_train, y_val, y_test, scaler


# BLOQUE 7 — Red neuronal (4 × 256)


def construir_red(input_dim, neuronas=256, n_capas=4, dropout=0.1):
    inp = layers.Input(shape=(input_dim,), name="entrada")
    x   = inp

    for i in range(n_capas):
        x = layers.Dense(neuronas, kernel_initializer='he_normal', name=f"densa_{i+1}")(x)
        x = layers.BatchNormalization(name=f"bn_{i+1}")(x)
        x = layers.Activation('elu', name=f"elu_{i+1}")(x)
        x = layers.Dropout(dropout, name=f"dropout_{i+1}")(x)

    salida = layers.Dense(1, activation='linear', name="precio_norm")(x)
    model  = models.Model(inputs=inp, outputs=salida, name="HestonSurrogate_4x256")
    model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='mse', metrics=['mae'])
    return model


def get_callbacks():
    return [
        callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-6, verbose=1),
        callbacks.ModelCheckpoint(filepath='mejor_modelo_heston.keras', monitor='val_loss',
                                  save_best_only=True, verbose=0)
    ]

# BLOQUE 8 — evalucaion


def evaluar_modelo(model, X_test, y_test, history=None):
    y_pred = model.predict(X_test, verbose=0).flatten()
    r2     = r2_score(y_test, y_pred)
    mae    = mean_absolute_error(y_test, y_pred)
    rmse   = np.sqrt(mean_squared_error(y_test, y_pred))

    print(f"\n  R²    : {r2:.6f}  {'✓ Excelente' if r2 > 0.99 else '▲ Aceptable' if r2 > 0.97 else '✗ Revisar'}")
    print(f"  MAE   : {mae:.6f}  →  {mae * S0:.4f} € error medio")
    print(f"  RMSE  : {rmse:.6f}  →  {rmse * S0:.4f} € RMSE")

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle("Evaluación — Red Neuronal Heston (4 × 256)", fontsize=14, fontweight='bold')

    if history:
        ax = axes[0]
        ax.semilogy(history.history['loss'],     label='Train', color='steelblue')
        ax.semilogy(history.history['val_loss'], label='Val',   color='tomato', ls='--')
        ax.set_title("Curva de Aprendizaje")
        ax.set_xlabel("Época")
        ax.set_ylabel("Pérdida MSE (log)")
        ax.legend(); ax.grid(True, alpha=0.3)

    ax     = axes[1]
    sample = np.random.choice(len(y_test), min(3000, len(y_test)), replace=False)
    ax.scatter(y_test[sample] * S0, y_pred[sample] * S0, alpha=0.3, s=5, color='steelblue')
    lim = max(y_test.max(), y_pred.max()) * S0 * 1.05
    ax.plot([0, lim], [0, lim], 'r--', lw=1.5, label='Predicción perfecta')
    ax.set_title(f"Precio Real vs Predicho  (R² = {r2:.5f})")
    ax.set_xlabel("Precio Real (€)"); ax.set_ylabel("Precio Predicho (€)")
    ax.legend(); ax.grid(True, alpha=0.3)

    ax      = axes[2]
    errores = (y_pred - y_test) * S0
    ax.hist(errores, bins=80, color='steelblue', edgecolor='white', linewidth=0.3)
    ax.axvline(0, color='red', ls='--', lw=1.5, label='Error = 0')
    ax.axvline(errores.mean(), color='orange', ls='-', lw=1.5,
               label=f'Media = {errores.mean():.4f} €')
    ax.set_title("Distribución del Error (Predicho − Real)")
    ax.set_xlabel("Error (€)"); ax.set_ylabel("Frecuencia")
    ax.legend(); ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig("evaluacion_red_heston.png", dpi=150, bbox_inches='tight')
    plt.show()

    return {"R2": r2, "MAE_norm": mae, "RMSE_norm": rmse,
            "MAE_eur": mae * S0, "RMSE_eur": rmse * S0}


# BLOQUE 9 — inferencia (pricer rápido)


def predecir_precio(model, scaler, kappa, theta, sigma, rho, v0, T, K):
    x_raw = np.array([[
        np.log(K / S0),
        np.sqrt(max(T, 1e-12)),
        kappa,
        np.log(max(theta, 1e-8)),
        sigma,
        rho,
        np.log(max(v0, 1e-8))
    ]])
    x_scaled = scaler.transform(x_raw)
    return float(model.predict(x_scaled, verbose=0)[0, 0] * S0)


# Main


if __name__ == "__main__":

    tf.random.set_seed(SEED)
    np.random.seed(SEED)
    t_inicio = time.time()

    print("═" * 55)
    print("  PASO 0 — Verificación fórmula cerrada vs Carr-Madan")
    print("═" * 55)
    params_ejemplo = [2.0, 0.04, 0.3, -0.7, 0.04]
    verificar_formula_cerrada(params_ejemplo, T=0.5, K=100.0)

    print("\n" + "═" * 55)
    print("  PASO 1 — Generación del dataset (100.000 filas)")
    print("═" * 55)
    df_final = crear_dataset(N_SUPERFICIES, outfile=OUTFILE)

    print("\n" + "═" * 55)
    print("  PASO 2 — Validación del dataset")
    print("═" * 55)
    validar_dataset(df_final)

    print("\n" + "═" * 55)
    print("  PASO 3 — Preparación de datos")
    print("═" * 55)
    X_train, X_val, X_test, y_train, y_val, y_test, scaler = preparar_datos(df_final)

    print("\n" + "═" * 55)
    print("  PASO 4 — Entrenamiento (4 capas × 256 neuronas)")
    print("═" * 55)
    model = construir_red(input_dim=X_train.shape[1])
    model.summary()

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=300,
        batch_size=512,
        callbacks=get_callbacks(),
        verbose=1
    )

    print("\n" + "═" * 55)
    print("  PASO 5 — Evaluación sobre test")
    print("═" * 55)
    metricas = evaluar_modelo(model, X_test, y_test, history=history)

    model.save('modelo_heston_final.keras')
    print("\n  Guardado: modelo_heston_final.keras")
    print("  Guardado: escalador_heston_nn.pkl")

    print("\n" + "═" * 55)
    print("  PASO 6 — Comparativa de velocidad: red vs fórmula cerrada")
    print("═" * 55)
    kappa, theta, sigma, rho, v0, T, K = 2.0, 0.04, 0.3, -0.7, 0.04, 0.5, 100.0
    N_REPS = 100

    # Heston
    tiempos_exacto = []
    for _ in range(N_REPS):
        t0 = time.perf_counter()
        precio_exacto = heston_precio_cerrado([kappa, theta, sigma, rho, v0], S0, r, T, K)
        tiempos_exacto.append((time.perf_counter() - t0) * 1000)
    t_exacto = np.mean(tiempos_exacto)

    # Red neuronal
    t0 = time.perf_counter()
    precio_nn = predecir_precio(model, scaler, kappa, theta, sigma, rho, v0, T, K)
    t_nn = (time.perf_counter() - t0) * 1000

    aceleracion = t_exacto / t_nn
    print(f"  Heston exacto : {precio_exacto:.6f} €  [{t_exacto:.3f} ms  (media {N_REPS} llamadas)]")
    print(f"  Red neuronal  : {precio_nn:.6f} €  [{t_nn:.3f} ms]")
    print(f"  Error abs.    : {abs(precio_exacto - precio_nn):.6f} €")
    print(f"  Aceleración   : ×{aceleracion:.1f} más rápido")
    print(f"\n  Tiempo total del proceso: {(time.time()-t_inicio)/60:.1f} min")
# Out:
# ═══════════════════════════════════════════════════════
#   PASO 0 — Verificación fórmula cerrada vs Carr-Madan
# ═══════════════════════════════════════════════════════
#
#   Heston 1993 (integración directa) : 5.446870 €
#   Carr-Madan FFT                    : 5.448949 €
#   Diferencia                        : 2.08e-03 €
#
# ═══════════════════════════════════════════════════════
#   PASO 1 — Generación del dataset (100.000 filas)
# ═══════════════════════════════════════════════════════
#
#   Superficies : 1,924  |  Puntos/sup: 52  |  Objetivo: 100,048 filas
#   Parámetros válidos: 1924 de 2295 intentos (83.8% aceptación)
#   [  500/1924]    25,948 filas  (2522 filas/s)  ETA: 29s
#   [ 1000/1924]    51,948 filas  (3547 filas/s)  ETA: 14s
#   [ 1500/1924]    77,948 filas  (4236 filas/s)  ETA: 5s
#
#   Archivo   : dataset_heston_100k.csv
#   Filas     : 100,048
#   Errores   : 0
#   Tiempo    : 21.4 s
#
# ═══════════════════════════════════════════════════════
#   PASO 2 — Validación del dataset
# ═══════════════════════════════════════════════════════
#
#   Filas totales    : 100,048
#   Paramsets únicos : 1,924
#   Feller cumplido  : True  ✓
#   Precios negativos: 0  ✓
#   Violac. arbitraje: 0  ✓
# ═══════════════════════════════════════════════════════
#   PASO 3 — Preparación de datos
# ═══════════════════════════════════════════════════════
#
#   Train :   70,096 filas  (1348 superficies)
#   Val   :   14,976 filas  (288 superficies)
#   Test  :   14,976 filas  (288 superficies)
#
# ═══════════════════════════════════════════════════════
#   PASO 4 — Entrenamiento (4 capas × 256 neuronas)
# ═══════════════════════════════════════════════════════
# Model: "HestonSurrogate_4x256"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ entrada (InputLayer)            │ (None, 7)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densa_1 (Dense)                 │ (None, 256)            │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 256)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_1 (Activation)              │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densa_2 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 256)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_2 (Activation)              │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densa_3 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 256)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_3 (Activation)              │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densa_4 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_4 (BatchNormalization)       │ (None, 256)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_4 (Activation)              │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ precio_norm (Dense)             │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,777 (796.00 KB)
#  Trainable params: 201,729 (788.00 KB)
#  Non-trainable params: 2,048 (8.00 KB)
# Epoch 1/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - loss: 0.1829 - mae: 0.3152 - val_loss: 0.0069 - val_mae: 0.0674 - learning_rate: 0.0010
# Epoch 2/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0666 - mae: 0.2017 - val_loss: 0.0025 - val_mae: 0.0399 - learning_rate: 0.0010
# Epoch 3/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 0.0338 - mae: 0.1436 - val_loss: 0.0010 - val_mae: 0.0257 - learning_rate: 0.0010
# Epoch 4/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0161 - mae: 0.0987 - val_loss: 2.7949e-04 - val_mae: 0.0134 - learning_rate: 0.0010
# Epoch 5/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0075 - mae: 0.0678 - val_loss: 1.5994e-04 - val_mae: 0.0102 - learning_rate: 0.0010
# Epoch 6/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0034 - mae: 0.0455 - val_loss: 7.9123e-05 - val_mae: 0.0067 - learning_rate: 0.0010
# Epoch 7/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0015 - mae: 0.0300 - val_loss: 6.6700e-05 - val_mae: 0.0063 - learning_rate: 0.0010
# Epoch 8/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 7.0755e-04 - mae: 0.0207 - val_loss: 6.4493e-05 - val_mae: 0.0062 - learning_rate: 0.0010
# Epoch 9/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 3.8052e-04 - mae: 0.0152 - val_loss: 6.0608e-05 - val_mae: 0.0059 - learning_rate: 0.0010
# Epoch 10/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - loss: 2.6065e-04 - mae: 0.0125 - val_loss: 6.0822e-05 - val_mae: 0.0059 - learning_rate: 0.0010
# Epoch 11/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 2.1215e-04 - mae: 0.0112 - val_loss: 5.6239e-05 - val_mae: 0.0057 - learning_rate: 0.0010
# Epoch 12/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 1.8722e-04 - mae: 0.0105 - val_loss: 5.3056e-05 - val_mae: 0.0056 - learning_rate: 0.0010
# Epoch 13/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.7674e-04 - mae: 0.0102 - val_loss: 5.4731e-05 - val_mae: 0.0057 - learning_rate: 0.0010
# Epoch 14/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6732e-04 - mae: 0.0099 - val_loss: 5.2295e-05 - val_mae: 0.0056 - learning_rate: 0.0010
# Epoch 15/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.6013e-04 - mae: 0.0097 - val_loss: 5.0650e-05 - val_mae: 0.0055 - learning_rate: 0.0010
# Epoch 16/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.5794e-04 - mae: 0.0096 - val_loss: 4.8511e-05 - val_mae: 0.0054 - learning_rate: 0.0010
# Epoch 17/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.5318e-04 - mae: 0.0095 - val_loss: 4.5684e-05 - val_mae: 0.0052 - learning_rate: 0.0010
# Epoch 18/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 1.4675e-04 - mae: 0.0093 - val_loss: 4.4431e-05 - val_mae: 0.0051 - learning_rate: 0.0010
# Epoch 19/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3959e-04 - mae: 0.0091
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.4353e-04 - mae: 0.0092 - val_loss: 4.3515e-05 - val_mae: 0.0051 - learning_rate: 0.0010
# Epoch 20/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 1.3035e-04 - mae: 0.0088 - val_loss: 3.6053e-05 - val_mae: 0.0046 - learning_rate: 5.0000e-04
# Epoch 21/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 1.2970e-04 - mae: 0.0087 - val_loss: 3.6337e-05 - val_mae: 0.0046 - learning_rate: 5.0000e-04
# Epoch 22/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.2826e-04 - mae: 0.0087 - val_loss: 3.5435e-05 - val_mae: 0.0046 - learning_rate: 5.0000e-04
# Epoch 23/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 1.2655e-04 - mae: 0.0086 - val_loss: 3.4925e-05 - val_mae: 0.0046 - learning_rate: 5.0000e-04
# Epoch 24/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 1.2786e-04 - mae: 0.0086 - val_loss: 3.5184e-05 - val_mae: 0.0046 - learning_rate: 5.0000e-04
# Epoch 25/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.2587e-04 - mae: 0.0086 - val_loss: 3.6050e-05 - val_mae: 0.0047 - learning_rate: 5.0000e-04
# Epoch 26/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2573e-04 - mae: 0.0086 - val_loss: 3.7452e-05 - val_mae: 0.0048 - learning_rate: 5.0000e-04
# Epoch 27/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2101e-04 - mae: 0.0084
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.2408e-04 - mae: 0.0085 - val_loss: 3.3509e-05 - val_mae: 0.0045 - learning_rate: 5.0000e-04
# Epoch 28/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 1.1373e-04 - mae: 0.0082 - val_loss: 2.9823e-05 - val_mae: 0.0042 - learning_rate: 2.5000e-04
# Epoch 29/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.1346e-04 - mae: 0.0081 - val_loss: 3.0041e-05 - val_mae: 0.0042 - learning_rate: 2.5000e-04
# Epoch 30/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.1328e-04 - mae: 0.0081 - val_loss: 2.8941e-05 - val_mae: 0.0041 - learning_rate: 2.5000e-04
# Epoch 31/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.1090e-04 - mae: 0.0080 - val_loss: 2.8723e-05 - val_mae: 0.0041 - learning_rate: 2.5000e-04
# Epoch 32/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.1323e-04 - mae: 0.0081 - val_loss: 2.9103e-05 - val_mae: 0.0042 - learning_rate: 2.5000e-04
# Epoch 33/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 1.1051e-04 - mae: 0.0080 - val_loss: 2.8944e-05 - val_mae: 0.0041 - learning_rate: 2.5000e-04
# Epoch 34/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.1060e-04 - mae: 0.0081 - val_loss: 2.8946e-05 - val_mae: 0.0042 - learning_rate: 2.5000e-04
# Epoch 35/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0933e-04 - mae: 0.0080
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 1.1131e-04 - mae: 0.0081 - val_loss: 2.8003e-05 - val_mae: 0.0041 - learning_rate: 2.5000e-04
# Epoch 36/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 1.0436e-04 - mae: 0.0078 - val_loss: 2.5671e-05 - val_mae: 0.0039 - learning_rate: 1.2500e-04
# Epoch 37/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.0386e-04 - mae: 0.0078 - val_loss: 2.5660e-05 - val_mae: 0.0039 - learning_rate: 1.2500e-04
# Epoch 38/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 1.0200e-04 - mae: 0.0077 - val_loss: 2.5089e-05 - val_mae: 0.0038 - learning_rate: 1.2500e-04
# Epoch 39/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 1.0261e-04 - mae: 0.0078 - val_loss: 2.5372e-05 - val_mae: 0.0039 - learning_rate: 1.2500e-04
# Epoch 40/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.0248e-04 - mae: 0.0077 - val_loss: 2.4897e-05 - val_mae: 0.0038 - learning_rate: 1.2500e-04
# Epoch 41/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.0183e-04 - mae: 0.0077 - val_loss: 2.5872e-05 - val_mae: 0.0039 - learning_rate: 1.2500e-04
# Epoch 42/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 1.0274e-04 - mae: 0.0077 - val_loss: 2.5753e-05 - val_mae: 0.0039 - learning_rate: 1.2500e-04
# Epoch 43/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.0075e-04 - mae: 0.0077
# Epoch 43: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 1.0206e-04 - mae: 0.0077 - val_loss: 2.4907e-05 - val_mae: 0.0038 - learning_rate: 1.2500e-04
# Epoch 44/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 9.8412e-05 - mae: 0.0076 - val_loss: 2.4775e-05 - val_mae: 0.0038 - learning_rate: 6.2500e-05
# Epoch 45/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - loss: 9.8658e-05 - mae: 0.0076 - val_loss: 2.5937e-05 - val_mae: 0.0039 - learning_rate: 6.2500e-05
# Epoch 46/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.7120e-05 - mae: 0.0075 - val_loss: 2.4588e-05 - val_mae: 0.0038 - learning_rate: 6.2500e-05
# Epoch 47/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.7781e-05 - mae: 0.0076 - val_loss: 2.5630e-05 - val_mae: 0.0039 - learning_rate: 6.2500e-05
# Epoch 48/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 9.7559e-05 - mae: 0.0076 - val_loss: 2.4459e-05 - val_mae: 0.0038 - learning_rate: 6.2500e-05
# Epoch 49/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.6816e-05 - mae: 0.0075 - val_loss: 2.3250e-05 - val_mae: 0.0037 - learning_rate: 6.2500e-05
# Epoch 50/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 9.7756e-05 - mae: 0.0075 - val_loss: 2.3912e-05 - val_mae: 0.0038 - learning_rate: 6.2500e-05
# Epoch 51/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 9.4566e-05 - mae: 0.0074
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 9.5537e-05 - mae: 0.0075 - val_loss: 2.3772e-05 - val_mae: 0.0038 - learning_rate: 6.2500e-05
# Epoch 52/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.5153e-05 - mae: 0.0074 - val_loss: 3.0745e-05 - val_mae: 0.0043 - learning_rate: 3.1250e-05
# Epoch 53/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 9.3697e-05 - mae: 0.0074 - val_loss: 2.7449e-05 - val_mae: 0.0041 - learning_rate: 3.1250e-05
# Epoch 54/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.4128e-05 - mae: 0.0074 - val_loss: 2.6056e-05 - val_mae: 0.0039 - learning_rate: 3.1250e-05
# Epoch 55/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 9.4114e-05 - mae: 0.0074 - val_loss: 2.8212e-05 - val_mae: 0.0041 - learning_rate: 3.1250e-05
# Epoch 56/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 9.3700e-05 - mae: 0.0074 - val_loss: 2.7033e-05 - val_mae: 0.0040 - learning_rate: 3.1250e-05
# Epoch 57/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 9.3839e-05 - mae: 0.0074 - val_loss: 2.6925e-05 - val_mae: 0.0040 - learning_rate: 3.1250e-05
# Epoch 58/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 9.3684e-05 - mae: 0.0074 - val_loss: 2.6858e-05 - val_mae: 0.0040 - learning_rate: 3.1250e-05
# Epoch 59/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 9.1270e-05 - mae: 0.0073
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 9.3049e-05 - mae: 0.0074 - val_loss: 2.6121e-05 - val_mae: 0.0039 - learning_rate: 3.1250e-05
# Epoch 60/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 9.1910e-05 - mae: 0.0073 - val_loss: 2.4275e-05 - val_mae: 0.0038 - learning_rate: 1.5625e-05
# Epoch 61/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 9.1075e-05 - mae: 0.0073 - val_loss: 2.3591e-05 - val_mae: 0.0037 - learning_rate: 1.5625e-05
# Epoch 62/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.1447e-05 - mae: 0.0073 - val_loss: 2.3162e-05 - val_mae: 0.0037 - learning_rate: 1.5625e-05
# Epoch 63/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 9.0916e-05 - mae: 0.0073 - val_loss: 2.3336e-05 - val_mae: 0.0037 - learning_rate: 1.5625e-05
# Epoch 64/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 9.0334e-05 - mae: 0.0072 - val_loss: 2.3608e-05 - val_mae: 0.0037 - learning_rate: 1.5625e-05
# Epoch 65/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 9.1322e-05 - mae: 0.0073 - val_loss: 2.4015e-05 - val_mae: 0.0038 - learning_rate: 1.5625e-05
# Epoch 66/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 9.1021e-05 - mae: 0.0073 - val_loss: 2.3000e-05 - val_mae: 0.0037 - learning_rate: 1.5625e-05
# Epoch 67/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.8000e-05 - mae: 0.0072
# Epoch 67: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 9.0298e-05 - mae: 0.0072 - val_loss: 2.3801e-05 - val_mae: 0.0038 - learning_rate: 1.5625e-05
# Epoch 68/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 8.8844e-05 - mae: 0.0072 - val_loss: 2.3064e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 69/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - loss: 8.8857e-05 - mae: 0.0072 - val_loss: 2.2978e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 70/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 8.8361e-05 - mae: 0.0072 - val_loss: 2.3324e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 71/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.7398e-05 - mae: 0.0071 - val_loss: 2.2927e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 72/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.8461e-05 - mae: 0.0072 - val_loss: 2.2962e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 73/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 8.8704e-05 - mae: 0.0072 - val_loss: 2.2983e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 74/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.8241e-05 - mae: 0.0071 - val_loss: 2.2313e-05 - val_mae: 0.0036 - learning_rate: 7.8125e-06
# Epoch 75/300
# 136/137 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.6838e-05 - mae: 0.0071
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.8383e-05 - mae: 0.0072 - val_loss: 2.3039e-05 - val_mae: 0.0037 - learning_rate: 7.8125e-06
# Epoch 76/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 8.7833e-05 - mae: 0.0071 - val_loss: 2.3153e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 77/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 8.7321e-05 - mae: 0.0071 - val_loss: 2.3376e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 78/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.6800e-05 - mae: 0.0071 - val_loss: 2.3312e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 79/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - loss: 8.7144e-05 - mae: 0.0071 - val_loss: 2.2948e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 80/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 8.7105e-05 - mae: 0.0071 - val_loss: 2.3337e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 81/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.7347e-05 - mae: 0.0071 - val_loss: 2.2858e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 82/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - loss: 8.5652e-05 - mae: 0.0070 - val_loss: 2.3143e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 83/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 8.4732e-05 - mae: 0.0070
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 8.5557e-05 - mae: 0.0071 - val_loss: 2.2930e-05 - val_mae: 0.0037 - learning_rate: 3.9063e-06
# Epoch 84/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 8.5884e-05 - mae: 0.0071 - val_loss: 2.2032e-05 - val_mae: 0.0036 - learning_rate: 1.9531e-06
# Epoch 85/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - loss: 8.4769e-05 - mae: 0.0070 - val_loss: 2.1907e-05 - val_mae: 0.0036 - learning_rate: 1.9531e-06
# Epoch 86/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss:
300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.7563e-05 - mae: 0.0062 - val_loss: 1.4555e-05 - val_mae: 0.0030 - learning_rate: 1.0000e-06
# Epoch 285/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 6.7933e-05 - mae: 0.0062 - val_loss: 1.4482e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 286/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 6.7296e-05 - mae: 0.0062 - val_loss: 1.4335e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 287/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 6.6863e-05 - mae: 0.0062 - val_loss: 1.4394e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 288/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.6757e-05 - mae: 0.0062 - val_loss: 1.4343e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 289/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 6.7724e-05 - mae: 0.0062 - val_loss: 1.4390e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 290/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 6.7269e-05 - mae: 0.0062 - val_loss: 1.4403e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 291/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 6.6797e-05 - mae: 0.0062 - val_loss: 1.4280e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 292/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 6.6829e-05 - mae: 0.0062 - val_loss: 1.4168e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 293/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 6.6779e-05 - mae: 0.0062 - val_loss: 1.4300e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 294/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 6.7037e-05 - mae: 0.0062 - val_loss: 1.4244e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 295/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 6.6467e-05 - mae: 0.0062 - val_loss: 1.4116e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 296/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 6.7386e-05 - mae: 0.0062 - val_loss: 1.4154e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 297/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 6.7187e-05 - mae: 0.0062 - val_loss: 1.4163e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 298/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 6.6993e-05 - mae: 0.0062 - val_loss: 1.4271e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 299/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 6.6292e-05 - mae: 0.0062 - val_loss: 1.4088e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Epoch 300/300
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 6.5894e-05 - mae: 0.0061 - val_loss: 1.4118e-05 - val_mae: 0.0029 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 299.
#
# ═══════════════════════════════════════════════════════
#   PASO 5 — Evaluación sobre test
# ═══════════════════════════════════════════════════════
#
#   R²    : 0.996065  ✓ Excelente
#   MAE   : 0.002956  →  0.2956 € error medio
#   RMSE  : 0.003872  →  0.3872 € RMSE
#   Guardado: modelo_heston_final.keras
#   Guardado: escalador_heston_nn.pkl
#
# ═══════════════════════════════════════════════════════
#   PASO 6 — Comparativa de velocidad: red vs fórmula cerrada
# ═══════════════════════════════════════════════════════
#   Heston exacto : 5.446870 €  [11.684 ms  (media 100 llamadas)]
#   Red neuronal  : 4.868030 €  [130.674 ms]
#   Error abs.    : 0.578840 €
#   Aceleración   : ×0.1 más rápido
#
#   Tiempo total del proceso: 21.2 min
